# %%
import zipfile
import numpy as np
import torch
import io
import os
import matplotlib.pyplot as plt
import random
import torch.nn as nn
import torch.optim as optim
from PIL import Image
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from torch.optim import lr_scheduler

# %%
'''
    The following are functions for the CNN. Note that the CNN structure needs to be updated
    when the image sizes are changed. 
'''

# Function 0
def calculate_accuracy(predictions, targets):
    '''
        This function evalautes the accurcay
    '''
    correct = (predictions == targets).sum().item()
    total = len(targets)
    return correct / total

# FUNCTION 1
def calculate_rmse(predictions, targets):
    '''
        This function calculates the RMSE
    '''
    return torch.sqrt(((predictions.float() - targets.float()) ** 2).mean())

# FUNCTION 2
def load_and_resize_images(zip_file_path, target_size=(250, 250)):
    '''
        This function reads the data zip file, ensures that images are 
        RGB (3 dimensional) and are 250x250 pixels.

        @zip_file_path is the dataset zip file directory
        @target_size is fixed at 250x250 since the dataset does not have larger 
        size images
    '''
    images = []
    labels = []
  
    with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
        for file_info in zip_ref.infolist():
            if file_info.filename.endswith(".jpg"):
                # Extract image data
                image_data = zip_ref.read(file_info.filename)

                # Get label from folder name
                label = os.path.dirname(file_info.filename)

                # Convert image data to PIL Image, convert to RGB, and resize
                image = Image.open(io.BytesIO(image_data)).convert('RGB')
                resized_image = image.resize(target_size)

                # Append image and label
                images.append(np.array(resized_image))  # Convert to NumPy array
                labels.append(label)
        
    return np.array(images), np.array(labels)

# FUNCTION 3
def reduce_data(images, labels, target_size=(64, 64), subset_ratio=1):
    '''
        This function reduced the images size to 64x64 pixels. The user can also
        set a subset ratio; that is the ratio of iamge samples from the whole data set
        when the dataset is very large

        @images is the image data
        @labels is the labels for the image data
        @target_size is fixed at 64x64 pixels
        @subset_ratio is ratio of the sample of the whole data set, by default it is 1 (whole dataset)
    '''
    reduced_images = []
    reduced_labels = []
    
    # Sample a subset
    subset_indices = random.sample(range(len(images)), int(subset_ratio * len(images)))

    for i in subset_indices:
        # Resize images
        resized_image = Image.fromarray(images[i]).resize(target_size)
        reduced_images.append(np.array(resized_image))
        reduced_labels.append(labels[i])

    return np.array(reduced_images), np.array(reduced_labels)

# CLASS 1
class SimplifiedCNN(nn.Module):
    ''' 
        Build a simple CNN model for 64x64 pixel images.
    '''
    def __init__(self):
        super(SimplifiedCNN, self).__init__()
        self.conv1 = nn.Conv2d(3, 16, kernel_size=3, stride=1, padding=1)
        self.bn1 = nn.BatchNorm2d(16)
        self.relu = nn.ReLU()
        self.maxpool = nn.MaxPool2d(kernel_size=2, stride=2)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, stride=1, padding=1)
        self.bn2 = nn.BatchNorm2d(32)
        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(32 * 16 * 16, 64)
        self.dropout = nn.Dropout(0.7)  # Adjust dropout rate
        self.fc2 = nn.Linear(64, len(label_encoder.classes_))

    def forward(self, x):
        x = self.conv1(x)
        x = self.bn1(x)
        x = self.relu(x)
        x = self.maxpool(x)
        x = self.conv2(x)
        x = self.bn2(x)
        x = self.relu(x)
        x = self.maxpool(x)
        x = self.flatten(x)
        x = self.fc1(x)
        x = self.relu(x)
        x = self.dropout(x)
        x = self.fc2(x)
        return x

# %%
# Load and resize images from the zip file
zip_file_path = 'archive.zip'
images, labels = load_and_resize_images(zip_file_path)

# Encode labels
label_encoder = LabelEncoder()
encoded_labels = label_encoder.fit_transform(labels)

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(images, encoded_labels, test_size=0.2, random_state=42)

# %%
# Sample 4 labels for visualization
sample_labels = np.unique(y_train)[:4]

# Display 4x5 grid with each row representing a sample of a specific label
num_rows = len(sample_labels)
num_columns = 5

fig, axes = plt.subplots(num_rows, num_columns, figsize=(15, 10))
for i, label in enumerate(sample_labels):
    # Select fixed number of samples (e.g., 5) for the current label
    samples_for_label = X_train[y_train == label][:5]

    # Display the samples in the current row
    for j in range(num_columns):
        axes[i, j].imshow(samples_for_label[j])
        axes[i, j].axis('off')

plt.show()

# %%
# Reduce data
X_train_reduced, y_train_reduced = reduce_data(X_train, y_train)
X_test_reduced, y_test_reduced = reduce_data(X_test, y_test)

# Encode labels for the test set
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train_reduced)
y_test_encoded = label_encoder.transform(y_test_reduced)

# Convert data to PyTorch tensors
X_train_tensor = torch.Tensor(X_train_reduced.transpose((0, 3, 1, 2)))  # Transpose to match PyTorch channel-first format
y_train_tensor = torch.Tensor(y_train_encoded).long()

X_test_tensor = torch.Tensor(X_test_reduced.transpose((0, 3, 1, 2)))  # Transpose to match PyTorch channel-first format
y_test_tensor = torch.Tensor(y_test_encoded).long()


# Instantiate the simplified model
simplified_model = SimplifiedCNN()

# Define the loss function and optimizer (using SGD this time)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(simplified_model.parameters(), lr=0.001, momentum=0.75)  # Adjust momentum if needed

# Learning rate scheduler
scheduler = lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.1)

# %%
# Lists to store training and testing losses and metrics
train_losses = []
test_losses = []
train_accuracy = []
test_accuracy = []

# Train the model
num_epochs = 120

for epoch in range(num_epochs):
    simplified_model.train()

    optimizer.zero_grad()
    output = simplified_model(X_train_tensor)
    loss = criterion(output, y_train_tensor)
    loss.backward()
    optimizer.step()

    # Compute and store training metrics
    predicted_train = torch.argmax(output, 1).numpy()
    y_train_np = y_train_tensor.numpy()
    train_accuracy.append(calculate_accuracy(predicted_train, y_train_np))

    # Store training loss
    train_losses.append(loss.item())

    # Evaluate the model on the test set
    simplified_model.eval()
    with torch.no_grad():
        test_output = simplified_model(X_test_tensor)
        test_loss = criterion(test_output, y_test_tensor)
        test_losses.append(test_loss.item())

        # Compute and store testing metrics
        predicted_test = torch.argmax(test_output, 1).numpy()
        y_test_np = y_test_tensor.numpy()
        test_accuracy.append(calculate_accuracy(predicted_test, y_test_np))

    # Print and plot the losses and metrics
    print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {loss.item():.4f}, Test Loss: {test_loss.item():.4f}, '
          f'Train Accuracy: {train_accuracy[-1]:.4f}, Test Accuracy: {test_accuracy[-1]:.4f}')
# Out:
# Epoch [1/120], Train Loss: 1.5317, Test Loss: 1.3729, Train Accuracy: 0.1339, Test Accuracy: 0.0887
# Epoch [2/120], Train Loss: 1.4503, Test Loss: 1.3210, Train Accuracy: 0.1936, Test Accuracy: 0.2635
# Epoch [3/120], Train Loss: 1.3345, Test Loss: 1.2837, Train Accuracy: 0.3115, Test Accuracy: 0.2831
# Epoch [4/120], Train Loss: 1.2429, Test Loss: 1.2534, Train Accuracy: 0.4312, Test Accuracy: 0.2875
# Epoch [5/120], Train Loss: 1.1755, Test Loss: 1.2226, Train Accuracy: 0.4787, Test Accuracy: 0.2964
# Epoch [6/120], Train Loss: 1.1283, Test Loss: 1.1880, Train Accuracy: 0.5016, Test Accuracy: 0.3807
# Epoch [7/120], Train Loss: 1.0823, Test Loss: 1.1517, Train Accuracy: 0.5386, Test Accuracy: 0.4419
# Epoch [8/120], Train Loss: 1.0356, Test Loss: 1.1177, Train Accuracy: 0.5553, Test Accuracy: 0.5049
# Epoch [9/120], Train Loss: 1.0203, Test Loss: 1.0851, Train Accuracy: 0.5515, Test Accuracy: 0.5421
# Epoch [10/120], Train Loss: 0.9830, Test Loss: 1.0534, Train Accuracy: 0.5864, Test Accuracy: 0.5688
# Epoch [11/120], Train Loss: 0.9540, Test Loss: 1.0217, Train Accuracy: 0.5921, Test Accuracy: 0.6069
# Epoch [12/120], Train Loss: 0.9319, Test Loss: 0.9905, Train Accuracy: 0.5986, Test Accuracy: 0.6327
# Epoch [13/120], Train Loss: 0.9154, Test Loss: 0.9617, Train Accuracy: 0.6088, Test Accuracy: 0.6504
# Epoch [14/120], Train Loss: 0.9045, Test Loss: 0.9361, Train Accuracy: 0.6019, Test Accuracy: 0.6708
# Epoch [15/120], Train Loss: 0.8729, Test Loss: 0.9138, Train Accuracy: 0.6383, Test Accuracy: 0.6823
# Epoch [16/120], Train Loss: 0.8755, Test Loss: 0.8931, Train Accuracy: 0.6208, Test Accuracy: 0.6930
# Epoch [17/120], Train Loss: 0.8645, Test Loss: 0.8751, Train Accuracy: 0.6243, Test Accuracy: 0.6948
# Epoch [18/120], Train Loss: 0.8556, Test Loss: 0.8574, Train Accuracy: 0.6314, Test Accuracy: 0.7054
# Epoch [19/120], Train Loss: 0.8377, Test Loss: 0.8401, Train Accuracy: 0.6461, Test Accuracy: 0.7187
# Epoch [20/120], Train Loss: 0.8263, Test Loss: 0.8220, Train Accuracy: 0.6483, Test Accuracy: 0.7249
# Epoch [21/120], Train Loss: 0.8076, Test Loss: 0.8037, Train Accuracy: 0.6587, Test Accuracy: 0.7356
# Epoch [22/120], Train Loss: 0.8000, Test Loss: 0.7843, Train Accuracy: 0.6634, Test Accuracy: 0.7391
# Epoch [23/120], Train Loss: 0.8005, Test Loss: 0.7671, Train Accuracy: 0.6650, Test Accuracy: 0.7516
# Epoch [24/120], Train Loss: 0.7944, Test Loss: 0.7523, Train Accuracy: 0.6596, Test Accuracy: 0.7533
# Epoch [25/120], Train Loss: 0.7831, Test Loss: 0.7405, Train Accuracy: 0.6747, Test Accuracy: 0.7569
# Epoch [26/120], Train Loss: 0.7673, Test Loss: 0.7308, Train Accuracy: 0.6756, Test Accuracy: 0.7578
# Epoch [27/120], Train Loss: 0.7664, Test Loss: 0.7227, Train Accuracy: 0.6705, Test Accuracy: 0.7578
# Epoch [28/120], Train Loss: 0.7616, Test Loss: 0.7141, Train Accuracy: 0.6803, Test Accuracy: 0.7578
# Epoch [29/120], Train Loss: 0.7464, Test Loss: 0.7042, Train Accuracy: 0.6912, Test Accuracy: 0.7640
# Epoch [30/120], Train Loss: 0.7516, Test Loss: 0.6941, Train Accuracy: 0.6785, Test Accuracy: 0.7675
# Epoch [31/120], Train Loss: 0.7309, Test Loss: 0.6828, Train Accuracy: 0.7014, Test Accuracy: 0.7773
# Epoch [32/120], Train Loss: 0.7328, Test Loss: 0.6732, Train Accuracy: 0.6898, Test Accuracy: 0.7817
# Epoch [33/120], Train Loss: 0.7181, Test Loss: 0.6651, Train Accuracy: 0.7032, Test Accuracy: 0.7870
# Epoch [34/120], Train Loss: 0.7168, Test Loss: 0.6571, Train Accuracy: 0.7138, Test Accuracy: 0.7924
# Epoch [35/120], Train Loss: 0.6965, Test Loss: 0.6475, Train Accuracy: 0.7267, Test Accuracy: 0.7977
# Epoch [36/120], Train Loss: 0.6989, Test Loss: 0.6390, Train Accuracy: 0.7109, Test Accuracy: 0.8030
# Epoch [37/120], Train Loss: 0.6937, Test Loss: 0.6307, Train Accuracy: 0.7169, Test Accuracy: 0.8039
# Epoch [38/120], Train Loss: 0.6888, Test Loss: 0.6216, Train Accuracy: 0.7229, Test Accuracy: 0.8030
# Epoch [39/120], Train Loss: 0.6946, Test Loss: 0.6127, Train Accuracy: 0.7105, Test Accuracy: 0.8083
# Epoch [40/120], Train Loss: 0.6683, Test Loss: 0.6052, Train Accuracy: 0.7365, Test Accuracy: 0.8137
# Epoch [41/120], Train Loss: 0.6867, Test Loss: 0.5983, Train Accuracy: 0.7154, Test Accuracy: 0.8128
# Epoch [42/120], Train Loss: 0.6780, Test Loss: 0.5897, Train Accuracy: 0.7189, Test Accuracy: 0.8154
# Epoch [43/120], Train Loss: 0.6669, Test Loss: 0.5804, Train Accuracy: 0.7309, Test Accuracy: 0.8181
# Epoch [44/120], Train Loss: 0.6618, Test Loss: 0.5709, Train Accuracy: 0.7327, Test Accuracy: 0.8234
# Epoch [45/120], Train Loss: 0.6584, Test Loss: 0.5625, Train Accuracy: 0.7327, Test Accuracy: 0.8270
# Epoch [46/120], Train Loss: 0.6489, Test Loss: 0.5565, Train Accuracy: 0.7436, Test Accuracy: 0.8287
# Epoch [47/120], Train Loss: 0.6357, Test Loss: 0.5504, Train Accuracy: 0.7451, Test Accuracy: 0.8296
# Epoch [48/120], Train Loss: 0.6421, Test Loss: 0.5435, Train Accuracy: 0.7393, Test Accuracy: 0.8323
# Epoch [49/120], Train Loss: 0.6291, Test Loss: 0.5366, Train Accuracy: 0.7520, Test Accuracy: 0.8314
# Epoch [50/120], Train Loss: 0.6295, Test Loss: 0.5289, Train Accuracy: 0.7442, Test Accuracy: 0.8376
# Epoch [51/120], Train Loss: 0.6267, Test Loss: 0.5222, Train Accuracy: 0.7560, Test Accuracy: 0.8376
# Epoch [52/120], Train Loss: 0.6177, Test Loss: 0.5159, Train Accuracy: 0.7595, Test Accuracy: 0.8394
# Epoch [53/120], Train Loss: 0.6228, Test Loss: 0.5100, Train Accuracy: 0.7502, Test Accuracy: 0.8412
# Epoch [54/120], Train Loss: 0.6201, Test Loss: 0.5055, Train Accuracy: 0.7536, Test Accuracy: 0.8421
# Epoch [55/120], Train Loss: 0.6028, Test Loss: 0.5023, Train Accuracy: 0.7642, Test Accuracy: 0.8412
# Epoch [56/120], Train Loss: 0.6166, Test Loss: 0.4982, Train Accuracy: 0.7509, Test Accuracy: 0.8429
# Epoch [57/120], Train Loss: 0.6029, Test Loss: 0.4937, Train Accuracy: 0.7669, Test Accuracy: 0.8429
# Epoch [58/120], Train Loss: 0.5946, Test Loss: 0.4885, Train Accuracy: 0.7709, Test Accuracy: 0.8429
# Epoch [59/120], Train Loss: 0.6054, Test Loss: 0.4832, Train Accuracy: 0.7587, Test Accuracy: 0.8447
# Epoch [60/120], Train Loss: 0.5970, Test Loss: 0.4792, Train Accuracy: 0.7651, Test Accuracy: 0.8438
# Epoch [61/120], Train Loss: 0.5962, Test Loss: 0.4759, Train Accuracy: 0.7598, Test Accuracy: 0.8438
# Epoch [62/120], Train Loss: 0.5839, Test Loss: 0.4718, Train Accuracy: 0.7700, Test Accuracy: 0.8456
# Epoch [63/120], Train Loss: 0.5819, Test Loss: 0.4676, Train Accuracy: 0.7771, Test Accuracy: 0.8465
# Epoch [64/120], Train Loss: 0.5856, Test Loss: 0.4643, Train Accuracy: 0.7622, Test Accuracy: 0.8447
# Epoch [65/120], Train Loss: 0.5833, Test Loss: 0.4600, Train Accuracy: 0.7749, Test Accuracy: 0.8456
# Epoch [66/120], Train Loss: 0.5739, Test Loss: 0.4561, Train Accuracy: 0.7755, Test Accuracy: 0.8465
# Epoch [67/120], Train Loss: 0.5844, Test Loss: 0.4530, Train Accuracy: 0.7726, Test Accuracy: 0.8447
# Epoch [68/120], Train Loss: 0.5787, Test Loss: 0.4501, Train Accuracy: 0.7802, Test Accuracy: 0.8456
# Epoch [69/120], Train Loss: 0.5638, Test Loss: 0.4473, Train Accuracy: 0.7873, Test Accuracy: 0.8492
# Epoch [70/120], Train Loss: 0.5648, Test Loss: 0.4455, Train Accuracy: 0.7769, Test Accuracy: 0.8483
# Epoch [71/120], Train Loss: 0.5654, Test Loss: 0.4428, Train Accuracy: 0.7791, Test Accuracy: 0.8474
# Epoch [72/120], Train Loss: 0.5649, Test Loss: 0.4401, Train Accuracy: 0.7804, Test Accuracy: 0.8465
# Epoch [73/120], Train Loss: 0.5509, Test Loss: 0.4381, Train Accuracy: 0.7871, Test Accuracy: 0.8474
# Epoch [74/120], Train Loss: 0.5534, Test Loss: 0.4356, Train Accuracy: 0.7815, Test Accuracy: 0.8500
# Epoch [75/120], Train Loss: 0.5480, Test Loss: 0.4326, Train Accuracy: 0.7893, Test Accuracy: 0.8527
# Epoch [76/120], Train Loss: 0.5559, Test Loss: 0.4296, Train Accuracy: 0.7948, Test Accuracy: 0.8527
# Epoch [77/120], Train Loss: 0.5516, Test Loss: 0.4267, Train Accuracy: 0.7840, Test Accuracy: 0.8527
# Epoch [78/120], Train Loss: 0.5496, Test Loss: 0.4238, Train Accuracy: 0.7820, Test Accuracy: 0.8545
# Epoch [79/120], Train Loss: 0.5512, Test Loss: 0.4213, Train Accuracy: 0.7855, Test Accuracy: 0.8571
# Epoch [80/120], Train Loss: 0.5396, Test Loss: 0.4188, Train Accuracy: 0.7951, Test Accuracy: 0.8571
# Epoch [81/120], Train Loss: 0.5457, Test Loss: 0.4163, Train Accuracy: 0.7955, Test Accuracy: 0.8580
# Epoch [82/120], Train Loss: 0.5306, Test Loss: 0.4142, Train Accuracy: 0.8017, Test Accuracy: 0.8598
# Epoch [83/120], Train Loss: 0.5393, Test Loss: 0.4125, Train Accuracy: 0.7906, Test Accuracy: 0.8634
# Epoch [84/120], Train Loss: 0.5479, Test Loss: 0.4112, Train Accuracy: 0.7924, Test Accuracy: 0.8625
# Epoch [85/120], Train Loss: 0.5302, Test Loss: 0.4096, Train Accuracy: 0.8042, Test Accuracy: 0.8625
# Epoch [86/120], Train Loss: 0.5430, Test Loss: 0.4087, Train Accuracy: 0.7897, Test Accuracy: 0.8616
# Epoch [87/120], Train Loss: 0.5281, Test Loss: 0.4069, Train Accuracy: 0.8000, Test Accuracy: 0.8616
# Epoch [88/120], Train Loss: 0.5313, Test Loss: 0.4050, Train Accuracy: 0.7982, Test Accuracy: 0.8607
# Epoch [89/120], Train Loss: 0.5152, Test Loss: 0.4025, Train Accuracy: 0.8079, Test Accuracy: 0.8607
# Epoch [90/120], Train Loss: 0.5207, Test Loss: 0.3995, Train Accuracy: 0.8075, Test Accuracy: 0.8616
# Epoch [91/120], Train Loss: 0.5260, Test Loss: 0.3967, Train Accuracy: 0.8104, Test Accuracy: 0.8625
# Epoch [92/120], Train Loss: 0.5240, Test Loss: 0.3945, Train Accuracy: 0.8015, Test Accuracy: 0.8642
# Epoch [93/120], Train Loss: 0.5139, Test Loss: 0.3925, Train Accuracy: 0.8088, Test Accuracy: 0.8669
# Epoch [94/120], Train Loss: 0.5151, Test Loss: 0.3901, Train Accuracy: 0.8057, Test Accuracy: 0.8705
# Epoch [95/120], Train Loss: 0.5109, Test Loss: 0.3879, Train Accuracy: 0.8142, Test Accuracy: 0.8713
# Epoch [96/120], Train Loss: 0.5047, Test Loss: 0.3863, Train Accuracy: 0.8088, Test Accuracy: 0.8705
# Epoch [97/120], Train Loss: 0.5089, Test Loss: 0.3851, Train Accuracy: 0.8102, Test Accuracy: 0.8696
# Epoch [98/120], Train Loss: 0.5095, Test Loss: 0.3834, Train Accuracy: 0.8119, Test Accuracy: 0.8696
# Epoch [99/120], Train Loss: 0.5013, Test Loss: 0.3819, Train Accuracy: 0.8091, Test Accuracy: 0.8696
# Epoch [100/120], Train Loss: 0.5036, Test Loss: 0.3809, Train Accuracy: 0.8124, Test Accuracy: 0.8696
# Epoch [101/120], Train Loss: 0.4884, Test Loss: 0.3801, Train Accuracy: 0.8186, Test Accuracy: 0.8705
# Epoch [102/120], Train Loss: 0.4968, Test Loss: 0.3788, Train Accuracy: 0.8097, Test Accuracy: 0.8705
# Epoch [103/120], Train Loss: 0.4952, Test Loss: 0.3775, Train Accuracy: 0.8131, Test Accuracy: 0.8705
# Epoch [104/120], Train Loss: 0.5004, Test Loss: 0.3761, Train Accuracy: 0.8190, Test Accuracy: 0.8705
# Epoch [105/120], Train Loss: 0.4934, Test Loss: 0.3743, Train Accuracy: 0.8124, Test Accuracy: 0.8722
# Epoch [106/120], Train Loss: 0.4848, Test Loss: 0.3725, Train Accuracy: 0.8219, Test Accuracy: 0.8749
# Epoch [107/120], Train Loss: 0.4946, Test Loss: 0.3708, Train Accuracy: 0.8186, Test Accuracy: 0.8758
# Epoch [108/120], Train Loss: 0.4775, Test Loss: 0.3690, Train Accuracy: 0.8159, Test Accuracy: 0.8740
# Epoch [109/120], Train Loss: 0.4828, Test Loss: 0.3675, Train Accuracy: 0.8193, Test Accuracy: 0.8784
# Epoch [110/120], Train Loss: 0.4864, Test Loss: 0.3661, Train Accuracy: 0.8146, Test Accuracy: 0.8776
# Epoch [111/120], Train Loss: 0.4771, Test Loss: 0.3651, Train Accuracy: 0.8266, Test Accuracy: 0.8776
# Epoch [112/120], Train Loss: 0.4852, Test Loss: 0.3644, Train Accuracy: 0.8197, Test Accuracy: 0.8776
# Epoch [113/120], Train Loss: 0.4745, Test Loss: 0.3637, Train Accuracy: 0.8210, Test Accuracy: 0.8776
# Epoch [114/120], Train Loss: 0.4833, Test Loss: 0.3630, Train Accuracy: 0.8164, Test Accuracy: 0.8776
# Epoch [115/120], Train Loss: 0.4802, Test Loss: 0.3624, Train Accuracy: 0.8253, Test Accuracy: 0.8776
# Epoch [116/120], Train Loss: 0.4780, Test Loss: 0.3615, Train Accuracy: 0.8230, Test Accuracy: 0.8776
# Epoch [117/120], Train Loss: 0.4809, Test Loss: 0.3603, Train Accuracy: 0.8286, Test Accuracy: 0.8784
# Epoch [118/120], Train Loss: 0.4682, Test Loss: 0.3592, Train Accuracy: 0.8277, Test Accuracy: 0.8784
# Epoch [119/120], Train Loss: 0.4740, Test Loss: 0.3580, Train Accuracy: 0.8237, Test Accuracy: 0.8793
# Epoch [120/120], Train Loss: 0.4753, Test Loss: 0.3566, Train Accuracy: 0.8242, Test Accuracy: 0.8802

# %%
# Plot the training and testing losses
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(range(1, num_epochs+1), train_losses, label='Training Loss')
plt.plot(range(1, num_epochs+1), test_losses, label='Testing Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Plot the training and testing RMSE
plt.subplot(1, 2, 2)
plt.plot(range(1, num_epochs+1), train_accuracy, label='Training Accuracy')
plt.plot(range(1, num_epochs+1), test_accuracy, label='Testing Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Lists to store sampled indices for each class
sampled_indices_per_class = {class_name: [] for class_name in label_encoder.classes_}

# Sample 5 images for each class
for class_label in label_encoder.classes_:
    class_indices = [i for i, label in enumerate(y_test_tensor) if label.item() == label_encoder.transform([class_label])[0]]
    sampled_indices = random.sample(class_indices, min(5, len(class_indices)))
    sampled_indices_per_class[class_label] = sampled_indices

# Display actual and predicted labels for the sampled images
for class_label, sampled_indices in sampled_indices_per_class.items():
    for i, sample_index in enumerate(sampled_indices):
        sample_image = X_test_tensor[sample_index].unsqueeze(0)  # Add batch dimension

        # Make a prediction using the trained model
        simplified_model.eval()
        with torch.no_grad():
            model_output = simplified_model(sample_image)
            predicted_label = torch.argmax(model_output, 1).item()

        # Convert labels back to their original class names
        predicted_class_name = label_encoder.classes_[predicted_label]
        actual_class_name = label_encoder.classes_[y_test_tensor[sample_index].item()]

        # Normalize pixel values to [0, 1]
        sample_image_normalized = sample_image.squeeze().permute(1, 2, 0).numpy() / 255.0

        # Display the sample image, actual label, and predicted label
        plt.subplot(4, 5, i + 1 + 5 * label_encoder.transform([class_label])[0])
        plt.imshow(sample_image_normalized)
        plt.title(f'Actual: {actual_class_name}\nPredicted: {predicted_class_name}')
        plt.axis('off')

plt.show()
