# %%
import zipfile
import numpy as np
import torch
import io
import os
import matplotlib.pyplot as plt
import random
import torch.nn as nn
import torch.optim as optim
from PIL import Image
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from torch.optim import lr_scheduler

# %%
'''
    The following are functions for the CNN. Note that the CNN structure needs to be updated
    when the image sizes are changed. 
'''

# FUNCTION 1
def calculate_rmse(predictions, targets):
    '''
        This function calculates the RMSE
    '''
    return torch.sqrt(((predictions.float() - targets.float()) ** 2).mean())

# FUNCTION 2
def load_and_resize_images(zip_file_path, target_size=(250, 250)):
    '''
        This function reads the data zip file, ensures that images are 
        RGB (3 dimensional) and are 250x250 pixels.

        @zip_file_path is the dataset zip file directory
        @target_size is fixed at 250x250 since the dataset does not have larger 
        size images
    '''
    images = []
    labels = []
  
    with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
        for file_info in zip_ref.infolist():
            if file_info.filename.endswith(".jpg"):
                # Extract image data
                image_data = zip_ref.read(file_info.filename)

                # Get label from folder name
                label = os.path.dirname(file_info.filename)

                # Convert image data to PIL Image, convert to RGB, and resize
                image = Image.open(io.BytesIO(image_data)).convert('RGB')
                resized_image = image.resize(target_size)

                # Append image and label
                images.append(np.array(resized_image))  # Convert to NumPy array
                labels.append(label)
        
    return np.array(images), np.array(labels)

# FUNCTION 3
def reduce_data(images, labels, target_size=(64, 64), subset_ratio=1):
    '''
        This function reduced the images size to 64x64 pixels. The user can also
        set a subset ratio; that is the ratio of iamge samples from the whole data set
        when the dataset is very large

        @images is the image data
        @labels is the labels for the image data
        @target_size is fixed at 64x64 pixels
        @subset_ratio is ratio of the sample of the whole data set, by default it is 1 (whole dataset)
    '''
    reduced_images = []
    reduced_labels = []
    
    # Sample a subset
    subset_indices = random.sample(range(len(images)), int(subset_ratio * len(images)))

    for i in subset_indices:
        # Resize images
        resized_image = Image.fromarray(images[i]).resize(target_size)
        reduced_images.append(np.array(resized_image))
        reduced_labels.append(labels[i])

    return np.array(reduced_images), np.array(reduced_labels)

# CLASS 1
class SimplifiedCNN(nn.Module):
    ''' 
        Build a simple CNN model for 64x64 pixel images.
    '''
    def __init__(self):
        super(SimplifiedCNN, self).__init__()
        self.conv1 = nn.Conv2d(3, 16, kernel_size=3, stride=1, padding=1)
        self.bn1 = nn.BatchNorm2d(16)
        self.relu = nn.ReLU()
        self.maxpool = nn.MaxPool2d(kernel_size=2, stride=2)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, stride=1, padding=1)
        self.bn2 = nn.BatchNorm2d(32)
        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(32 * 16 * 16, 64)
        self.dropout = nn.Dropout(0.7)  # Adjust dropout rate
        self.fc2 = nn.Linear(64, len(label_encoder.classes_))

    def forward(self, x):
        x = self.conv1(x)
        x = self.bn1(x)
        x = self.relu(x)
        x = self.maxpool(x)
        x = self.conv2(x)
        x = self.bn2(x)
        x = self.relu(x)
        x = self.maxpool(x)
        x = self.flatten(x)
        x = self.fc1(x)
        x = self.relu(x)
        x = self.dropout(x)
        x = self.fc2(x)
        return x

# %%
# Load and resize images from the zip file
zip_file_path = 'archive.zip'
images, labels = load_and_resize_images(zip_file_path)

# Encode labels
label_encoder = LabelEncoder()
encoded_labels = label_encoder.fit_transform(labels)

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(images, encoded_labels, test_size=0.1, random_state=42)

# %%
# Sample 4 labels for visualization
sample_labels = np.unique(y_train)[:4]

# Display 4x5 grid with each row representing a sample of a specific label
num_rows = len(sample_labels)
num_columns = 5

fig, axes = plt.subplots(num_rows, num_columns, figsize=(15, 10))
for i, label in enumerate(sample_labels):
    # Select fixed number of samples (e.g., 5) for the current label
    samples_for_label = X_train[y_train == label][:5]

    # Display the samples in the current row
    for j in range(num_columns):
        axes[i, j].imshow(samples_for_label[j])
        axes[i, j].axis('off')

plt.show()

# %%
# Reduce data
X_train_reduced, y_train_reduced = reduce_data(X_train, y_train)
X_test_reduced, y_test_reduced = reduce_data(X_test, y_test)

# Encode labels for the test set
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train_reduced)
y_test_encoded = label_encoder.transform(y_test_reduced)

# Convert data to PyTorch tensors
X_train_tensor = torch.Tensor(X_train_reduced.transpose((0, 3, 1, 2)))  # Transpose to match PyTorch channel-first format
y_train_tensor = torch.Tensor(y_train_encoded).long()

X_test_tensor = torch.Tensor(X_test_reduced.transpose((0, 3, 1, 2)))  # Transpose to match PyTorch channel-first format
y_test_tensor = torch.Tensor(y_test_encoded).long()


# Instantiate the simplified model
simplified_model = SimplifiedCNN()

# Define the loss function and optimizer (using SGD this time)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(simplified_model.parameters(), lr=0.001, momentum=0.75)  # Adjust momentum if needed

# Learning rate scheduler
scheduler = lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.1)

# %%
# Lists to store training and testing losses and RMSE
train_losses = []
test_losses = []
train_rmse = []
test_rmse = []

# Variables to store correct predictions for overall accuracy
correct_train_predictions = 0
correct_test_predictions = 0

# Variables to store total number of samples
total_train_samples = 0
total_test_samples = 0

# Train the model
num_epochs = 100

for epoch in range(num_epochs):
    simplified_model.train()

    optimizer.zero_grad()
    output = simplified_model(X_train_tensor)
    loss = criterion(output, y_train_tensor)
    loss.backward()
    optimizer.step()

    # Compute and store training RMSE
    predicted_train = torch.argmax(output, 1)
    train_rmse.append(calculate_rmse(predicted_train, y_train_tensor))

    # Update correct_train_predictions and total_train_samples
    correct_train_predictions += (predicted_train == y_train_tensor).sum().item()
    total_train_samples += len(y_train_tensor)

    # Store training loss
    train_losses.append(loss.item())

    # Evaluate the model on the test set
    simplified_model.eval()
    with torch.no_grad():
        test_output = simplified_model(X_test_tensor)
        test_loss = criterion(test_output, y_test_tensor)
        test_losses.append(test_loss.item())

        # Compute and store testing RMSE
        predicted_test = torch.argmax(test_output, 1)
        test_rmse.append(calculate_rmse(predicted_test, y_test_tensor))

        # Update correct_test_predictions and total_test_samples
        correct_test_predictions += (predicted_test == y_test_tensor).sum().item()
        total_test_samples += len(y_test_tensor)

    # Print and plot the losses
    print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {loss.item():.4f}, Test Loss: {test_loss.item():.4f}, '
          f'Train RMSE: {train_rmse[-1]:.4f}, Test RMSE: {test_rmse[-1]:.4f}')

# Calculate overall accuracy
overall_train_accuracy = correct_train_predictions / total_train_samples
overall_test_accuracy = correct_test_predictions / total_test_samples

print(f'Overall Training Accuracy: {overall_train_accuracy * 100:.2f}%')
print(f'Overall Testing Accuracy: {overall_test_accuracy * 100:.2f}%')
# Out:
# Epoch [1/100], Train Loss: 1.4622, Test Loss: 1.4979, Train RMSE: 1.7973, Test RMSE: 1.9051
# Epoch [2/100], Train Loss: 1.4201, Test Loss: 1.4139, Train RMSE: 1.7517, Test RMSE: 1.8826
# Epoch [3/100], Train Loss: 1.3490, Test Loss: 1.3706, Train RMSE: 1.5890, Test RMSE: 1.6281
# Epoch [4/100], Train Loss: 1.2709, Test Loss: 1.3348, Train RMSE: 1.3229, Test RMSE: 0.9991
# Epoch [5/100], Train Loss: 1.2218, Test Loss: 1.3064, Train RMSE: 1.2331, Test RMSE: 0.9848
# Epoch [6/100], Train Loss: 1.1831, Test Loss: 1.2791, Train RMSE: 1.2212, Test RMSE: 1.0476
# Epoch [7/100], Train Loss: 1.1453, Test Loss: 1.2531, Train RMSE: 1.1901, Test RMSE: 1.0711
# Epoch [8/100], Train Loss: 1.1194, Test Loss: 1.2272, Train RMSE: 1.1784, Test RMSE: 1.0408
# Epoch [9/100], Train Loss: 1.0917, Test Loss: 1.2014, Train RMSE: 1.1585, Test RMSE: 0.9947
# Epoch [10/100], Train Loss: 1.0712, Test Loss: 1.1750, Train RMSE: 1.1393, Test RMSE: 0.9694
# Epoch [11/100], Train Loss: 1.0460, Test Loss: 1.1477, Train RMSE: 1.1026, Test RMSE: 0.9453
# Epoch [12/100], Train Loss: 1.0196, Test Loss: 1.1184, Train RMSE: 1.0731, Test RMSE: 0.9434
# Epoch [13/100], Train Loss: 1.0003, Test Loss: 1.0887, Train RMSE: 1.0649, Test RMSE: 0.9340
# Epoch [14/100], Train Loss: 0.9919, Test Loss: 1.0587, Train RMSE: 1.0572, Test RMSE: 0.9264
# Epoch [15/100], Train Loss: 0.9722, Test Loss: 1.0282, Train RMSE: 1.0533, Test RMSE: 0.9060
# Epoch [16/100], Train Loss: 0.9395, Test Loss: 0.9973, Train RMSE: 1.0112, Test RMSE: 0.8922
# Epoch [17/100], Train Loss: 0.9281, Test Loss: 0.9651, Train RMSE: 0.9993, Test RMSE: 0.8619
# Epoch [18/100], Train Loss: 0.9028, Test Loss: 0.9343, Train RMSE: 0.9627, Test RMSE: 0.8464
# Epoch [19/100], Train Loss: 0.8892, Test Loss: 0.9061, Train RMSE: 0.9730, Test RMSE: 0.8316
# Epoch [20/100], Train Loss: 0.8750, Test Loss: 0.8813, Train RMSE: 0.9658, Test RMSE: 0.8208
# Epoch [21/100], Train Loss: 0.8685, Test Loss: 0.8593, Train RMSE: 0.9689, Test RMSE: 0.8219
# Epoch [22/100], Train Loss: 0.8517, Test Loss: 0.8404, Train RMSE: 0.9363, Test RMSE: 0.8121
# Epoch [23/100], Train Loss: 0.8338, Test Loss: 0.8236, Train RMSE: 0.9121, Test RMSE: 0.8067
# Epoch [24/100], Train Loss: 0.8217, Test Loss: 0.8074, Train RMSE: 0.9038, Test RMSE: 0.7776
# Epoch [25/100], Train Loss: 0.8226, Test Loss: 0.7918, Train RMSE: 0.9161, Test RMSE: 0.7473
# Epoch [26/100], Train Loss: 0.8064, Test Loss: 0.7755, Train RMSE: 0.8939, Test RMSE: 0.7426
# Epoch [27/100], Train Loss: 0.7934, Test Loss: 0.7586, Train RMSE: 0.8940, Test RMSE: 0.7378
# Epoch [28/100], Train Loss: 0.7984, Test Loss: 0.7423, Train RMSE: 0.8850, Test RMSE: 0.6995
# Epoch [29/100], Train Loss: 0.7771, Test Loss: 0.7268, Train RMSE: 0.8879, Test RMSE: 0.6945
# Epoch [30/100], Train Loss: 0.7739, Test Loss: 0.7113, Train RMSE: 0.8935, Test RMSE: 0.6945
# Epoch [31/100], Train Loss: 0.7655, Test Loss: 0.6969, Train RMSE: 0.8671, Test RMSE: 0.6803
# Epoch [32/100], Train Loss: 0.7578, Test Loss: 0.6833, Train RMSE: 0.8797, Test RMSE: 0.6631
# Epoch [33/100], Train Loss: 0.7584, Test Loss: 0.6694, Train RMSE: 0.8818, Test RMSE: 0.6302
# Epoch [34/100], Train Loss: 0.7493, Test Loss: 0.6561, Train RMSE: 0.8695, Test RMSE: 0.6174
# Epoch [35/100], Train Loss: 0.7432, Test Loss: 0.6440, Train RMSE: 0.8618, Test RMSE: 0.6145
# Epoch [36/100], Train Loss: 0.7284, Test Loss: 0.6324, Train RMSE: 0.8442, Test RMSE: 0.5940
# Epoch [37/100], Train Loss: 0.7215, Test Loss: 0.6213, Train RMSE: 0.8370, Test RMSE: 0.5712
# Epoch [38/100], Train Loss: 0.7194, Test Loss: 0.6110, Train RMSE: 0.8515, Test RMSE: 0.5554
# Epoch [39/100], Train Loss: 0.7181, Test Loss: 0.6014, Train RMSE: 0.8551, Test RMSE: 0.5506
# Epoch [40/100], Train Loss: 0.7055, Test Loss: 0.5925, Train RMSE: 0.8116, Test RMSE: 0.5474
# Epoch [41/100], Train Loss: 0.7093, Test Loss: 0.5844, Train RMSE: 0.8733, Test RMSE: 0.5409
# Epoch [42/100], Train Loss: 0.6940, Test Loss: 0.5771, Train RMSE: 0.8329, Test RMSE: 0.5259
# Epoch [43/100], Train Loss: 0.6979, Test Loss: 0.5704, Train RMSE: 0.8391, Test RMSE: 0.5242
# Epoch [44/100], Train Loss: 0.6930, Test Loss: 0.5642, Train RMSE: 0.7921, Test RMSE: 0.5070
# Epoch [45/100], Train Loss: 0.6974, Test Loss: 0.5579, Train RMSE: 0.8316, Test RMSE: 0.4892
# Epoch [46/100], Train Loss: 0.6855, Test Loss: 0.5520, Train RMSE: 0.8237, Test RMSE: 0.4708
# Epoch [47/100], Train Loss: 0.6842, Test Loss: 0.5468, Train RMSE: 0.8177, Test RMSE: 0.4727
# Epoch [48/100], Train Loss: 0.6812, Test Loss: 0.5419, Train RMSE: 0.8375, Test RMSE: 0.4535
# Epoch [49/100], Train Loss: 0.6667, Test Loss: 0.5375, Train RMSE: 0.7863, Test RMSE: 0.4535
# Epoch [50/100], Train Loss: 0.6685, Test Loss: 0.5333, Train RMSE: 0.8092, Test RMSE: 0.4516
# Epoch [51/100], Train Loss: 0.6695, Test Loss: 0.5293, Train RMSE: 0.7839, Test RMSE: 0.4516
# Epoch [52/100], Train Loss: 0.6651, Test Loss: 0.5256, Train RMSE: 0.7822, Test RMSE: 0.4335
# Epoch [53/100], Train Loss: 0.6555, Test Loss: 0.5220, Train RMSE: 0.7786, Test RMSE: 0.4315
# Epoch [54/100], Train Loss: 0.6603, Test Loss: 0.5183, Train RMSE: 0.7933, Test RMSE: 0.4496
# Epoch [55/100], Train Loss: 0.6477, Test Loss: 0.5144, Train RMSE: 0.7546, Test RMSE: 0.4476
# Epoch [56/100], Train Loss: 0.6563, Test Loss: 0.5109, Train RMSE: 0.8016, Test RMSE: 0.4436
# Epoch [57/100], Train Loss: 0.6556, Test Loss: 0.5078, Train RMSE: 0.7975, Test RMSE: 0.4436
# Epoch [58/100], Train Loss: 0.6429, Test Loss: 0.5047, Train RMSE: 0.7943, Test RMSE: 0.4436
# Epoch [59/100], Train Loss: 0.6344, Test Loss: 0.5018, Train RMSE: 0.7736, Test RMSE: 0.4476
# Epoch [60/100], Train Loss: 0.6447, Test Loss: 0.4991, Train RMSE: 0.7851, Test RMSE: 0.4476
# Epoch [61/100], Train Loss: 0.6296, Test Loss: 0.4963, Train RMSE: 0.7594, Test RMSE: 0.4476
# Epoch [62/100], Train Loss: 0.6429, Test Loss: 0.4936, Train RMSE: 0.7689, Test RMSE: 0.4456
# Epoch [63/100], Train Loss: 0.6335, Test Loss: 0.4911, Train RMSE: 0.7493, Test RMSE: 0.4273
# Epoch [64/100], Train Loss: 0.6349, Test Loss: 0.4886, Train RMSE: 0.7542, Test RMSE: 0.4273
# Epoch [65/100], Train Loss: 0.6285, Test Loss: 0.4863, Train RMSE: 0.7596, Test RMSE: 0.4082
# Epoch [66/100], Train Loss: 0.6279, Test Loss: 0.4838, Train RMSE: 0.7438, Test RMSE: 0.4082
# Epoch [67/100], Train Loss: 0.6198, Test Loss: 0.4815, Train RMSE: 0.7404, Test RMSE: 0.3859
# Epoch [68/100], Train Loss: 0.6119, Test Loss: 0.4792, Train RMSE: 0.7408, Test RMSE: 0.3882
# Epoch [69/100], Train Loss: 0.6095, Test Loss: 0.4771, Train RMSE: 0.7410, Test RMSE: 0.3813
# Epoch [70/100], Train Loss: 0.6201, Test Loss: 0.4753, Train RMSE: 0.7522, Test RMSE: 0.3859
# Epoch [71/100], Train Loss: 0.6057, Test Loss: 0.4735, Train RMSE: 0.7173, Test RMSE: 0.3647
# Epoch [72/100], Train Loss: 0.6132, Test Loss: 0.4714, Train RMSE: 0.7531, Test RMSE: 0.3647
# Epoch [73/100], Train Loss: 0.6143, Test Loss: 0.4694, Train RMSE: 0.7435, Test RMSE: 0.3695
# Epoch [74/100], Train Loss: 0.6106, Test Loss: 0.4674, Train RMSE: 0.7580, Test RMSE: 0.3695
# Epoch [75/100], Train Loss: 0.5960, Test Loss: 0.4653, Train RMSE: 0.7250, Test RMSE: 0.3695
# Epoch [76/100], Train Loss: 0.6013, Test Loss: 0.4632, Train RMSE: 0.7076, Test RMSE: 0.3695
# Epoch [77/100], Train Loss: 0.6009, Test Loss: 0.4612, Train RMSE: 0.7343, Test RMSE: 0.3719
# Epoch [78/100], Train Loss: 0.5902, Test Loss: 0.4594, Train RMSE: 0.7020, Test RMSE: 0.3719
# Epoch [79/100], Train Loss: 0.5874, Test Loss: 0.4578, Train RMSE: 0.6938, Test RMSE: 0.3743
# Epoch [80/100], Train Loss: 0.5926, Test Loss: 0.4561, Train RMSE: 0.7176, Test RMSE: 0.3695
# Epoch [81/100], Train Loss: 0.5982, Test Loss: 0.4545, Train RMSE: 0.7035, Test RMSE: 0.3695
# Epoch [82/100], Train Loss: 0.5853, Test Loss: 0.4528, Train RMSE: 0.7120, Test RMSE: 0.3695
# Epoch [83/100], Train Loss: 0.5773, Test Loss: 0.4513, Train RMSE: 0.7061, Test RMSE: 0.3743
# Epoch [84/100], Train Loss: 0.5966, Test Loss: 0.4499, Train RMSE: 0.7343, Test RMSE: 0.3790
# Epoch [85/100], Train Loss: 0.5791, Test Loss: 0.4483, Train RMSE: 0.6914, Test RMSE: 0.3790
# Epoch [86/100], Train Loss: 0.5862, Test Loss: 0.4468, Train RMSE: 0.7132, Test RMSE: 0.3859
# Epoch [87/100], Train Loss: 0.5805, Test Loss: 0.4454, Train RMSE: 0.6972, Test RMSE: 0.3882
# Epoch [88/100], Train Loss: 0.5756, Test Loss: 0.4438, Train RMSE: 0.6990, Test RMSE: 0.3905
# Epoch [89/100], Train Loss: 0.5722, Test Loss: 0.4421, Train RMSE: 0.6884, Test RMSE: 0.3882
# Epoch [90/100], Train Loss: 0.5698, Test Loss: 0.4406, Train RMSE: 0.7026, Test RMSE: 0.3928
# Epoch [91/100], Train Loss: 0.5702, Test Loss: 0.4390, Train RMSE: 0.6927, Test RMSE: 0.3950
# Epoch [92/100], Train Loss: 0.5668, Test Loss: 0.4377, Train RMSE: 0.6658, Test RMSE: 0.3950
# Epoch [93/100], Train Loss: 0.5658, Test Loss: 0.4364, Train RMSE: 0.6817, Test RMSE: 0.3972
# Epoch [94/100], Train Loss: 0.5587, Test Loss: 0.4350, Train RMSE: 0.6882, Test RMSE: 0.4017
# Epoch [95/100], Train Loss: 0.5654, Test Loss: 0.4336, Train RMSE: 0.7047, Test RMSE: 0.3813
# Epoch [96/100], Train Loss: 0.5544, Test Loss: 0.4323, Train RMSE: 0.6631, Test RMSE: 0.3836
# Epoch [97/100], Train Loss: 0.5613, Test Loss: 0.4309, Train RMSE: 0.6708, Test RMSE: 0.3836
# Epoch [98/100], Train Loss: 0.5489, Test Loss: 0.4297, Train RMSE: 0.6729, Test RMSE: 0.4061
# Epoch [99/100], Train Loss: 0.5512, Test Loss: 0.4287, Train RMSE: 0.6872, Test RMSE: 0.4253
# Epoch [100/100], Train Loss: 0.5495, Test Loss: 0.4275, Train RMSE: 0.6828, Test RMSE: 0.4253
# Overall Training Accuracy: 68.23%
# Overall Testing Accuracy: 79.60%

# %%
# Plot the training and testing losses
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(range(1, num_epochs+1), train_losses, label='Training Loss')
plt.plot(range(1, num_epochs+1), test_losses, label='Testing Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Plot the training and testing RMSE
plt.subplot(1, 2, 2)
plt.plot(range(1, num_epochs+1), train_rmse, label='Training RMSE')
plt.plot(range(1, num_epochs+1), test_rmse, label='Testing RMSE')
plt.xlabel('Epoch')
plt.ylabel('RMSE')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Lists to store sampled indices for each class
sampled_indices_per_class = {class_name: [] for class_name in label_encoder.classes_}

# Sample 5 images for each class
for class_label in label_encoder.classes_:
    class_indices = [i for i, label in enumerate(y_test_tensor) if label.item() == label_encoder.transform([class_label])[0]]
    sampled_indices = random.sample(class_indices, min(5, len(class_indices)))
    sampled_indices_per_class[class_label] = sampled_indices

# Display actual and predicted labels for the sampled images
for class_label, sampled_indices in sampled_indices_per_class.items():
    for i, sample_index in enumerate(sampled_indices):
        sample_image = X_test_tensor[sample_index].unsqueeze(0)  # Add batch dimension

        # Make a prediction using the trained model
        simplified_model.eval()
        with torch.no_grad():
            model_output = simplified_model(sample_image)
            predicted_label = torch.argmax(model_output, 1).item()

        # Convert labels back to their original class names
        predicted_class_name = label_encoder.classes_[predicted_label]
        actual_class_name = label_encoder.classes_[y_test_tensor[sample_index].item()]

        # Normalize pixel values to [0, 1]
        sample_image_normalized = sample_image.squeeze().permute(1, 2, 0).numpy() / 255.0

        # Display the sample image, actual label, and predicted label
        plt.subplot(4, 5, i + 1 + 5 * label_encoder.transform([class_label])[0])
        plt.imshow(sample_image_normalized)
        plt.title(f'Actual: {actual_class_name}\nPredicted: {predicted_class_name}')
        plt.axis('off')

plt.show()
